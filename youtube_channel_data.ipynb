# %%
import googleapiclient.discovery
import os
import sqlite3
from datetime import datetime
import csv
import isodate

# %%
# find channel ids

# Set up API key
API_KEY = '###############'  # Replace with your API key

# Initialize YouTube API client
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=API_KEY)

# Function to get channel ID from handle
def get_channel_id_from_handle(youtube, handle):
    request = youtube.search().list(
        part='snippet',
        q=handle,
        type='channel'
    )
    response = request.execute()
    
    if 'items' in response:
        return response['items'][0]['snippet']['channelId']
    else:
        return None

# Handles of three different youtube banks
handles = ('@KOHOFinancial','@Wise', '@tangerinebank')

channel_ids_dict = {}
for handle in handles:
    channel_id = get_channel_id_from_handle(youtube, handle)
    if channel_id:
        channel_ids_dict.update({handle: channel_id})


print(channel_ids_dict)
# Out:
# {'@KOHOFinancial': 'UC-HnC-dcg5_KYW6pQ7H4JQA', '@Wise': 'UCm4E1b5TjstT8UUIk7mb-MA', '@tangerinebank': 'UCsMDZ4GA5pgLAxjc8TKjFiQ'}

# %%
#api returning wrong channel id
channel_ids_dict['@Wise']= 'UCm4E1b5TjstT8UUIk7mb-MA'
print(channel_ids_dict)
# Out:
# {'@KOHOFinancial': 'UC-HnC-dcg5_KYW6pQ7H4JQA', '@Wise': 'UCm4E1b5TjstT8UUIk7mb-MA', '@tangerinebank': 'UCsMDZ4GA5pgLAxjc8TKjFiQ'}

# %%
# List of YouTube channel IDs for the three bank channels
channel_ids = list(channel_ids_dict.values())


# Function to get channel statistics
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=','.join(channel_ids)
    )
    response = request.execute()
    
    for item in response['items']:
        data = {
            'channel_id': item['id'],
            'title': item['snippet']['title'],
            'subscribers': item['statistics']['subscriberCount'],
            'views': item['statistics']['viewCount'],
            'total_videos': item['statistics']['videoCount'],
            'playlist_id': item['contentDetails']['relatedPlaylists']['uploads']
        }
        all_data.append(data)
    
    return all_data

# Function to get video IDs from a playlist
def get_video_ids(youtube, playlist_id):
    video_ids = []
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
    
    return video_ids

# Function to get video details
def get_video_details(youtube, video_ids, channel_stats):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part='snippet,contentDetails,statistics',
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()
        
        for video in response['items']:
            try:
                # Find the channel_id from channel_stats based on video's channelId
                channel_id = next((ch['channel_id'] for ch in channel_stats if ch['channel_id'] == video['snippet']['channelId']), None)
                
                if channel_id:
                    # Extract duration in ISO 8601 format from contentDetails
                    duration = video['contentDetails']['duration']
                    # Parse duration to get total seconds
                    duration_parsed = isodate.parse_duration(duration)
                    duration_seconds = duration_parsed.total_seconds()
                    
                    video_stats = {
                        'video_id': video['id'],
                        'title': video['snippet']['title'],
                        'published_at': video['snippet']['publishedAt'],
                        'views': video['statistics'].get('viewCount', 0),
                        'likes': video['statistics'].get('likeCount', 0),
                        'comments': video['statistics'].get('commentCount', 0),
                        'channel_id': channel_id,
                        'duration_seconds': duration_seconds
                    }
                    all_video_stats.append(video_stats)
                else:
                    print(f"No matching channel found for video with channelId: {video['snippet']['channelId']}")
            except KeyError as e:
                print(f"KeyError: {e} for video: {video}")
                continue  # Skip this video and proceed with the next
        
    return all_video_stats



# Fetch channel statistics
channel_stats = get_channel_stats(youtube, channel_ids)

# Fetch video details for each channel
for channel in channel_stats:
    print(f"Fetching videos for channel: {channel['title']}")
    playlist_id = channel['playlist_id']
    video_ids = get_video_ids(youtube, playlist_id)
    video_details = get_video_details(youtube, video_ids, channel_stats)
    
    # Print or save the video details
    for video in video_details:
        print(video)

# Print channel statistics
for channel in channel_stats:
    print(channel)
# Out:
# Fetching videos for channel: Wise
# {'video_id': '1lPHoPkeccU', 'title': "Why These EU Countries Don't Use the Euro Currency? 🤔💶 #WiseMoneyStories", 'published_at': '2024-07-10T12:58:26Z', 'views': '1669', 'likes': '34', 'comments': '7', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 45.0}
# {'video_id': 'CtA8s7HOflA', 'title': 'Wise Travel Card: REAL TEST & Review on a Norway Road Trip 🚗', 'published_at': '2024-07-05T16:46:43Z', 'views': '1370', 'likes': '68', 'comments': '29', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 276.0}
# {'video_id': '449OLZ9mwsQ', 'title': 'What It Really Costs to Be a Musician... 💸  #musicgear #musicianlife #wisecard', 'published_at': '2024-07-01T13:00:04Z', 'views': '464', 'likes': '16', 'comments': '2', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 12.0}
# {'video_id': 'EtIFZBeiVYU', 'title': "How to say 'Pardon me' in 6 Languages 🗣️🌏", 'published_at': '2024-06-29T12:00:20Z', 'views': '3067', 'likes': '50', 'comments': '4', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 40.0}
# {'video_id': 'v78PqgbM0-4', 'title': 'Who Spent the Most on their Hen Do or a Stag? 💰', 'published_at': '2024-06-27T15:00:59Z', 'views': '529', 'likes': '15', 'comments': '11', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 52.0}
# {'video_id': 'EvcfTzV7WRo', 'title': 'How to Receive Money with Wise in 2024: The Most Up-to-Date & Complete Guide ✅', 'published_at': '2024-06-25T15:13:03Z', 'views': '2863', 'likes': '103', 'comments': '74', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 420.0}
# {'video_id': '5aUHvg-qz_Q', 'title': 'Moving to Brazil: How Much Will It Cost? 🇧🇷', 'published_at': '2024-06-14T14:10:20Z', 'views': '580', 'likes': '16', 'comments': '1', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 56.0}
# {'video_id': '-fv0HfNicE4', 'title': 'Moving to the USA: How Much Will it Cost? 🇺🇸 #usa', 'published_at': '2024-06-06T15:00:00Z', 'views': '398', 'likes': '20', 'comments': '3', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 56.0}
# {'video_id': 'OOZZ8_rwH0c', 'title': 'WorldRemit vs Wise: What You Need to Know Before Sending Money 💡', 'published_at': '2024-06-06T13:01:46Z', 'views': '922', 'likes': '65', 'comments': '25', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 340.0}
# {'video_id': 'sN14_RixEc0', 'title': 'Exploring London with £100: Hidden Gems! 🌟🇬🇧', 'published_at': '2024-06-02T11:37:44Z', 'views': '566', 'likes': '17', 'comments': '1', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 51.0}
# {'video_id': 'QPGu1y6gjyc', 'title': 'Crazy Money Stories #1 - @Wise', 'published_at': '2024-05-30T10:57:28Z', 'views': '4082', 'likes': '46', 'comments': '8', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 52.0}
# {'video_id': 'K2-9hacDAzc', 'title': 'Traveling with Wise Card: My Honest Review After 3 Weeks Trip ✈️', 'published_at': '2024-05-28T15:00:53Z', 'views': '9067', 'likes': '191', 'comments': '33', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 278.0}
# {'video_id': 'ubjsIlSWenw', 'title': 'How to Send Money With Wise: Newest Guide by Wise (2024)', 'published_at': '2024-05-08T16:04:36Z', 'views': '25557', 'likes': '356', 'comments': '213', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 299.0}
# {'video_id': 'YGEAZVlCKHE', 'title': 'Countries with the highest ATM withdrawal fees', 'published_at': '2024-05-03T13:15:12Z', 'views': '1116', 'likes': '40', 'comments': '8', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 34.0}
# {'video_id': 'gejbDVl4KxE', 'title': 'How to Avoid Foreign ATM Fees When Traveling Abroad 🌎', 'published_at': '2024-04-24T12:30:23Z', 'views': '1741', 'likes': '77', 'comments': '52', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 295.0}
# {'video_id': 'BJgVL8dkN5c', 'title': 'Why do they do this? Truth About Money Transfers', 'published_at': '2024-04-17T12:00:15Z', 'views': '2462', 'likes': '65', 'comments': '7', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 36.0}
# {'video_id': 'U7rS4UCGvDw', 'title': 'Wise vs Revolut - Your Ultimate Guide to Making the Right Choice', 'published_at': '2024-04-10T13:20:33Z', 'views': '11967', 'likes': '221', 'comments': '85', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 438.0}
# {'video_id': 'FY0hSYhjyoQ', 'title': 'Western Union Transfers: Fees & Rates Review 🔍🤯 (& alternative)', 'published_at': '2024-03-29T10:59:15Z', 'views': '2377', 'likes': '68', 'comments': '29', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 228.0}
# {'video_id': 'u8fc-EH2X64', 'title': "❗Every Payment Abroad May Result in Money Loss - Here's How #traveltips #travelcard", 'published_at': '2024-03-27T09:50:19Z', 'views': '2677', 'likes': '56', 'comments': '2', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 53.0}
# {'video_id': 'myQvKQBlUUI', 'title': 'From PayPal to Wise: Quick Withdrawal Guide by Wise ✅', 'published_at': '2024-03-22T16:30:55Z', 'views': '13557', 'likes': '302', 'comments': '122', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 225.0}
# {'video_id': 'f5XSnmU2nOw', 'title': "Receive Money on PayPal in 2024? Think Twice...🤔 Here's Why", 'published_at': '2024-03-15T14:06:17Z', 'views': '2852', 'likes': '98', 'comments': '26', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 385.0}
# {'video_id': 'O1CrEmeDLPs', 'title': 'Wise Card – Wise Gear for #contentcreator #cameragear', 'published_at': '2024-03-07T09:31:14Z', 'views': '5183', 'likes': '83', 'comments': '2', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 10.0}
# {'video_id': 'hQjcIdmdc6c', 'title': '🧑\u200d🎓 Student Bank Account Alternative in 2024: The Wise Choice', 'published_at': '2024-03-05T18:39:56Z', 'views': '1946', 'likes': '75', 'comments': '33', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 442.0}
# {'video_id': 'VgFl8IPupqY', 'title': 'The #1 Cost-Saving Tip for Travelers & Nomads Revealed! #travelhacks', 'published_at': '2024-02-28T11:55:46Z', 'views': '605', 'likes': '30', 'comments': '0', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 31.0}
# {'video_id': 'gx850CqFA1Q', 'title': 'Travel Smart: 4 Top Tips to PROTECT Your Card from Scams & Fees Abroad❗(2024)', 'published_at': '2024-02-23T14:43:02Z', 'views': '1658', 'likes': '83', 'comments': '18', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 307.0}
# {'video_id': 'Clb4l_KehJc', 'title': '💰 How I Save THOUSANDS on International Money Transfers! #moneytransfer', 'published_at': '2024-02-20T13:52:52Z', 'views': '801', 'likes': '40', 'comments': '3', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 42.0}
# {'video_id': 'AwphCOozUV0', 'title': "Traveling Soon? ✈️ Don't Fly Without Watching This! #traveltips", 'published_at': '2024-02-17T09:52:05Z', 'views': '848', 'likes': '38', 'comments': '3', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 37.0}
# {'video_id': '8HAZ1kbgVzU', 'title': '📲 The Ultimate Travel App: How to Set Up & Use Wise for Your 2024 Travels', 'published_at': '2024-02-13T16:18:34Z', 'views': '6245', 'likes': '162', 'comments': '59', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 411.0}
# {'video_id': 'dowG7k__D1s', 'title': '3 Indicators That Your Bank Card is Outdated in 2024 ❌💳', 'published_at': '2024-02-09T15:25:18Z', 'views': '2964', 'likes': '137', 'comments': '6', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 56.0}
# {'video_id': 'xSay5OgNm3Y', 'title': 'How To Add Money to Wise Debit & Digital Cards: Easy Top Up Guide (2024, updated ✅)', 'published_at': '2024-02-06T13:35:07Z', 'views': '27718', 'likes': '279', 'comments': '51', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 210.0}
# {'video_id': '5RvbhBFDVgk', 'title': 'Wise Account Verification ✅: Easy Guide (2024)', 'published_at': '2024-01-26T13:26:13Z', 'views': '12961', 'likes': '123', 'comments': '101', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 220.0}
# {'video_id': '-q1dfOPeLO8', 'title': 'The Dark Side of Free Money Transfers #moneytransfer #moneytransferapp', 'published_at': '2024-01-23T13:00:42Z', 'views': '1662', 'likes': '48', 'comments': '2', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 34.0}
# {'video_id': 'R_W3lmOHBKo', 'title': '😍 My New Wise Eco Card Unpacked! #ecofriendly #ecotraveler', 'published_at': '2024-01-16T12:06:21Z', 'views': '4434', 'likes': '179', 'comments': '32', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 49.0}
# {'video_id': 'qhVLc4xemO8', 'title': 'Your Debit Card May Eat Into Your Budget When Abroad 💸 Travel Smart! #travelhacks #travelcard', 'published_at': '2024-01-14T17:51:19Z', 'views': '1368', 'likes': '52', 'comments': '3', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 48.0}
# {'video_id': 'py32kLLG5RQ', 'title': "What's the Wise Money Transfers Speed In Reality? And How to Speed it Up 🚀", 'published_at': '2024-01-11T19:10:27Z', 'views': '2196', 'likes': '73', 'comments': '31', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 213.0}
# {'video_id': 'HDMqb5ALIh0', 'title': 'How To Add Wise Cards to Apple Pay \uf8ff - Two Ways #wisecard #applepay', 'published_at': '2023-12-22T16:54:51Z', 'views': '2557', 'likes': '65', 'comments': '12', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 21.0}
# {'video_id': 'rDw-kqQ-Xcs', 'title': '🍃 This Debit Card Is Eco-friendly Travel Essential #ecofriendly', 'published_at': '2023-12-20T18:18:04Z', 'views': '1271', 'likes': '50', 'comments': '21', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 44.0}
# {'video_id': 'oSQ1WeVFgjI', 'title': 'Wise Eco Card vs. Green: The Ultimate Comparison ✅', 'published_at': '2023-12-15T14:09:16Z', 'views': '6932', 'likes': '151', 'comments': '57', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 163.0}
# {'video_id': 'msdRGPd2q3A', 'title': "ATMs Abroad: You Shouldn't Let Them Convert Your Money! 🌍💸  #traveltips", 'published_at': '2023-11-29T11:10:44Z', 'views': '1489', 'likes': '38', 'comments': '6', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 26.0}
# {'video_id': 'wXsKLSHvTWs', 'title': 'Millions of Travelers Use THIS to Save On Currency Conversions ✅ #traveltips #money #travelplanning', 'published_at': '2023-11-28T16:10:37Z', 'views': '1035', 'likes': '30', 'comments': '0', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 23.0}
# {'video_id': 'uMGzNjxKCwU', 'title': 'How To Transfer Big Money Amounts Online 💰: Step-By-Step Guide with Wise', 'published_at': '2023-11-27T16:17:10Z', 'views': '17720', 'likes': '137', 'comments': '50', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 408.0}
# {'video_id': 'W4CFaQ6XtRY', 'title': 'The Travel Mistake We ALL Make 🗺️ #traveltips #traveladvice #travelhacks', 'published_at': '2023-11-23T10:44:44Z', 'views': '1369', 'likes': '40', 'comments': '0', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 30.0}
# {'video_id': 'K04iNypUoRQ', 'title': 'A Big NO For Your Travels! ❌ #traveladvice  #travelhacks #traveltips', 'published_at': '2023-11-21T14:38:40Z', 'views': '1103', 'likes': '29', 'comments': '0', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 22.0}
# {'video_id': 'W8NpTol-8nc', 'title': 'Your Travel Game-Changer: This Card Minimizes Conversion Expenses! #traveltips #travelhacks', 'published_at': '2023-11-18T10:34:09Z', 'views': '919', 'likes': '29', 'comments': '2', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 25.0}
# {'video_id': 'The9gfCfzzg', 'title': "Airport Money Exchange: They Won't Tell You This Truth... 🛫💸", 'published_at': '2023-11-17T11:03:44Z', 'views': '2783', 'likes': '45', 'comments': '14', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 203.0}
# {'video_id': 'BL0mXPaSFPo', 'title': 'ATM Trick You Should Be Aware Of ❗ #traveltips #travelhacks', 'published_at': '2023-11-10T09:10:52Z', 'views': '3256', 'likes': '108', 'comments': '2', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 49.0}
# {'video_id': 'NXcL28xykDk', 'title': 'How to Send Money to India Fast and Cheap! 🇮🇳 Wise Money Transfers', 'published_at': '2023-11-08T13:03:17Z', 'views': '24527', 'likes': '253', 'comments': '183', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 260.0}
# {'video_id': 'GiMy_aR6KBM', 'title': 'Traveling On A Budget Tip - Take This With You 🧳 #traveltips #budgettravel', 'published_at': '2023-11-03T10:18:13Z', 'views': '1055', 'likes': '44', 'comments': '4', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 35.0}
# {'video_id': 'kXACbuWDnhg', 'title': 'ATM Usage Is Risky Without This Knowledge 💳 - #atm #shorts #moneytips', 'published_at': '2023-10-31T22:32:48Z', 'views': '899', 'likes': '21', 'comments': '2', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 23.0}
# {'video_id': 'oa60dATTLRI', 'title': 'How to Use an ATM Like a PRO in 2024', 'published_at': '2023-10-30T13:38:56Z', 'views': '13810', 'likes': '328', 'comments': '42', 'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'duration_seconds': 265.0}
# Fetching videos for channel: KOHO
# {'video_id': 'jytOQGfaqYU', 'title': 'KOHO | NACO Summit 2024 | Daniel Eberhard', 'published_at': '2024-05-16T01:18:47Z', 'views': '350', 'likes': '8', 'comments': '2', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 2489.0}
# {'video_id': 'k11pAeDVxLs', 'title': "KOHO | We've Been Busy | What We've Shipped So Far In 2024 | Daniel Eberhard", 'published_at': '2024-05-06T21:15:01Z', 'views': '227', 'likes': '16', 'comments': '3', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 67.0}
# {'video_id': 'HgK18qxjEBo', 'title': 'KOHO | Meet Coach KOHO | 15s | Proud Sponsor of the NBA Playoffs', 'published_at': '2024-04-29T13:52:10Z', 'views': '45216', 'likes': '23', 'comments': '2', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 16.0}
# {'video_id': '_YHIW3t7oV0', 'title': 'KOHO | Meet Coach KOHO | Proud Partner of the NBA', 'published_at': '2024-04-29T13:32:43Z', 'views': '95890', 'likes': '16', 'comments': '0', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 31.0}
# {'video_id': '9X9y1_dchxM', 'title': 'KOHO I Origin Story + Announcement I Daniel Eberhard', 'published_at': '2024-01-29T14:16:05Z', 'views': '14386', 'likes': '609', 'comments': '145', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 102.0}
# {'video_id': 'FP_saIMDogU', 'title': 'KOHO | End of Year Update 2023 | Daniel Eberhard', 'published_at': '2023-12-21T14:00:09Z', 'views': '6789', 'likes': '299', 'comments': '68', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 96.0}
# {'video_id': 'p0-_wHKja5Q', 'title': 'What is KOHO? Spend, Save & Build Credit History All In One App', 'published_at': '2023-11-21T20:13:43Z', 'views': '6720116', 'likes': '181', 'comments': '4', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 37.0}
# {'video_id': 'KFuJh1TdGVg', 'title': '1 Million KOHO Users', 'published_at': '2023-07-17T18:05:51Z', 'views': '350', 'likes': '9', 'comments': '3', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 40.0}
# {'video_id': 'KXxCyL5jpVs', 'title': 'Michelle - My KOHO Card', 'published_at': '2023-07-11T17:58:56Z', 'views': '536', 'likes': '5', 'comments': '0', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 38.0}
# {'video_id': 'ANE8Ifrfplg', 'title': 'Gia - Getting Cash Back and Setting Goals with KOHO', 'published_at': '2023-07-11T17:57:40Z', 'views': '276', 'likes': '3', 'comments': '0', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 42.0}
# {'video_id': 'AFVsfBgu7Xw', 'title': 'Dhairya - Building Credit History with KOHO', 'published_at': '2023-07-11T17:57:08Z', 'views': '349', 'likes': '4', 'comments': '0', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 43.0}
# {'video_id': 'JAyikwY487g', 'title': 'KOHO - Credit History', 'published_at': '2022-10-14T15:39:25Z', 'views': '1046881', 'likes': '19', 'comments': '2', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 14.0}
# {'video_id': 'GOH0ln6KqOo', 'title': 'KOHO Premium Account — Earn 2% Cash Back On 3 Spending Categories — Reloadable Prepaid Mastercard', 'published_at': '2022-07-05T16:07:38Z', 'views': '2831', 'likes': '22', 'comments': '7', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 28.0}
# {'video_id': '8S2_YuyE1F4', 'title': 'KOHO Earn Interest— Earn 1.2% Interest on Your Entire Balance — High Interest Savings Account', 'published_at': '2022-07-05T16:07:34Z', 'views': '716', 'likes': '4', 'comments': '0', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 16.0}
# {'video_id': '88qjSOuhfjo', 'title': 'KOHO: Made For Your Money', 'published_at': '2022-03-21T18:19:19Z', 'views': '2876184', 'likes': '101', 'comments': '18', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 31.0}
# {'video_id': 'baaD_o0PRO8', 'title': 'KOHO Presents: The Museum of BS (Bank Stuff)', 'published_at': '2021-11-09T14:33:06Z', 'views': '556113', 'likes': '76', 'comments': '14', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 60.0}
# {'video_id': '-M_1jxaIC_Y', 'title': 'KOHO Metal Card Colour Reveal — Reloadable Prepaid Visa Card — No-Fee Spending Account & Fintech App', 'published_at': '2019-11-27T22:01:19Z', 'views': '4336', 'likes': '37', 'comments': '39', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 23.0}
# {'video_id': 'MTJxMIR0uCo', 'title': 'KOHO Metal Cards Teaser — Reloadable Prepaid Visa Card — No-Fee Spending Account & Budgeting App', 'published_at': '2019-11-14T21:14:18Z', 'views': '7668', 'likes': '15', 'comments': '8', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 19.0}
# {'video_id': 'q49BSC_LinI', 'title': 'The Triplets — Money Conversations — KOHO', 'published_at': '2019-05-10T17:34:56Z', 'views': '9628', 'likes': '5', 'comments': '1', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 95.0}
# {'video_id': 'MwMsEy4tzio', 'title': 'Rob + Curtis — Money Conversations — KOHO', 'published_at': '2019-04-25T18:14:01Z', 'views': '51857', 'likes': '14', 'comments': '1', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 99.0}
# {'video_id': 'PEHvN7qtY_k', 'title': 'Romana — Money Conversations — KOHO', 'published_at': '2019-03-22T21:07:54Z', 'views': '17138', 'likes': '17', 'comments': '3', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 96.0}
# {'video_id': 'kUs709I_uDE', 'title': 'Anne — Money Conversations — KOHO', 'published_at': '2019-03-08T21:56:40Z', 'views': '19916', 'likes': '20', 'comments': '2', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 95.0}
# {'video_id': 'Eo7DFB-Z80w', 'title': 'Dan — Money Conversations — KOHO', 'published_at': '2018-12-19T21:50:20Z', 'views': '41574', 'likes': '140', 'comments': '25', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 93.0}
# {'video_id': 'b4Nqxn9ev98', 'title': 'Ashley — Money Conversations — KOHO', 'published_at': '2018-12-10T14:01:56Z', 'views': '16147', 'likes': '16', 'comments': '2', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 67.0}
# {'video_id': 'r5qJBd9deXU', 'title': 'Tim — Money Conversations — KOHO', 'published_at': '2018-11-13T14:18:10Z', 'views': '35244', 'likes': '19', 'comments': '5', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 85.0}
# {'video_id': 'IRC0Onzigrw', 'title': 'Nicolle  — Money Conversations — KOHO', 'published_at': '2018-11-02T17:34:25Z', 'views': '2315', 'likes': '31', 'comments': '3', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 94.0}
# {'video_id': 'OFO2qA30CCQ', 'title': 'Feeling The Love!', 'published_at': '2018-09-17T16:15:14Z', 'views': '1486', 'likes': '26', 'comments': '4', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 103.0}
# {'video_id': 'nJnfcYFAmxg', 'title': 'Koho Live Stream', 'published_at': '2016-04-21T00:58:23Z', 'views': '0', 'likes': '0', 'comments': '0', 'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'duration_seconds': 0.0}
# Fetching videos for channel: Tangerine
# {'video_id': 'kt7MzqfyXsA', 'title': 'Five smart ways to start a budget', 'published_at': '2024-06-18T19:45:26Z', 'views': '271', 'likes': 0, 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 103.0}
# {'video_id': 'givsL6jJQZk', 'title': 'Cinq astuces pour établir un budget', 'published_at': '2024-06-18T19:41:38Z', 'views': '31', 'likes': 0, 'comments': 0, 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 118.0}
# {'video_id': 'yYvPIGML_LY', 'title': '60 secondes pour comprendre les CPG', 'published_at': '2024-06-03T14:39:11Z', 'views': '94', 'likes': 0, 'comments': 0, 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 98.0}
# {'video_id': 'duMfSiImuu8', 'title': 'Understand GICs in 60 Seconds', 'published_at': '2024-05-28T14:28:42Z', 'views': '254', 'likes': 0, 'comments': 0, 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 100.0}
# {'video_id': 'e0y0o76kH9s', 'title': 'Comprendre intérêts composés en une minute', 'published_at': '2024-05-23T13:44:29Z', 'views': '86', 'likes': 0, 'comments': 0, 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 104.0}
# {'video_id': 'yWTP-e44N5g', 'title': 'Understand compound interest in 60 seconds', 'published_at': '2024-05-09T19:29:10Z', 'views': '131', 'likes': 0, 'comments': 0, 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 113.0}
# {'video_id': 'ZXMolXEH6l0', 'title': 'Saying no to scams', 'published_at': '2024-04-22T19:43:05Z', 'views': '94', 'likes': '1', 'comments': 0, 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 61.0}
# {'video_id': 'PCqKlbL-WTk', 'title': 'Top things to know about RSPs', 'published_at': '2024-01-10T20:01:51Z', 'views': '1225', 'likes': 0, 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 176.0}
# {'video_id': 'NKXjLwGITAU', 'title': 'Les principales choses à savoir sur les RÉR', 'published_at': '2024-01-10T20:01:18Z', 'views': '408', 'likes': 0, 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 207.0}
# {'video_id': 'VassAEudttU', 'title': 'What are you saving for?', 'published_at': '2023-11-03T17:40:33Z', 'views': '310', 'likes': 0, 'comments': '4', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 139.0}
# {'video_id': 'hiUBc-QKi90', 'title': 'Pourquoi épargnez-vous?', 'published_at': '2023-11-03T16:19:12Z', 'views': '182', 'likes': 0, 'comments': '1', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 139.0}
# {'video_id': 'pOdPHPYljRU', 'title': "Pushing Women's Sports Forward", 'published_at': '2023-05-31T14:47:00Z', 'views': '172', 'likes': '3', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 11.0}
# {'video_id': 'YH9HOv06d2A', 'title': "Pushing Women's Sports Forward", 'published_at': '2023-05-31T14:38:31Z', 'views': '87', 'likes': '1', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 11.0}
# {'video_id': '6Qn8yeP_Eok', 'title': 'Tangerine Trade Deadline - Make the move to Tangerine', 'published_at': '2023-05-02T15:36:24Z', 'views': '842', 'likes': '6', 'comments': '2', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 31.0}
# {'video_id': 'zzN8VG4qjrE', 'title': "Pushing Women's Sports Forward", 'published_at': '2023-05-01T16:17:27Z', 'views': '870', 'likes': '12', 'comments': '2', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 31.0}
# {'video_id': '3_mvAGdmiak', 'title': 'Kneading Dough Canada with Nick Nurse, presented by Tangerine', 'published_at': '2023-04-18T19:38:09Z', 'views': '105', 'likes': '2', 'comments': '1', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 1139.0}
# {'video_id': 'XVBU0Nch9wU', 'title': 'Comment vous protéger contre la fraude', 'published_at': '2023-04-10T17:07:57Z', 'views': '195', 'likes': '2', 'comments': '1', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 101.0}
# {'video_id': '6-Uc6SMe218', 'title': 'How to protect yourself from fraud', 'published_at': '2023-04-05T19:20:07Z', 'views': '500', 'likes': '8', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 61.0}
# {'video_id': 'uXRlqebY3n4', 'title': 'Tangerine | Les acrobaties', 'published_at': '2023-03-14T19:54:16Z', 'views': '1299', 'likes': '12', 'comments': '5', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 31.0}
# {'video_id': '-Tz6n-EW_uA', 'title': 'Tangerine | Jumping Through Hoops', 'published_at': '2023-03-14T19:54:06Z', 'views': '305388', 'likes': '67', 'comments': '16', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 31.0}
# {'video_id': 'Pi8CiQkyUEw', 'title': 'Seven things to know about Tax-Free Savings Accounts (TFSAs)', 'published_at': '2022-11-01T15:40:14Z', 'views': '6089', 'likes': '16', 'comments': '6', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 118.0}
# {'video_id': 'L7zsEXZ46fA', 'title': "Sept choses à savoir sur les comptes d'épargne libres d'impôt (CÉLI)", 'published_at': '2022-11-01T15:40:09Z', 'views': '2181', 'likes': '5', 'comments': '2', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 118.0}
# {'video_id': 'hYYzNYdeKow', 'title': 'Cagnotte Tir dans le mille de Tangerine - Raptors 22/23', 'published_at': '2022-10-21T16:04:07Z', 'views': '399', 'likes': '0', 'comments': '1', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 16.0}
# {'video_id': 'OguJncBRHps', 'title': 'Tangerine Bank Shot Account - Raptors 22/23', 'published_at': '2022-10-19T13:43:51Z', 'views': '3942', 'likes': '6', 'comments': '6', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 31.0}
# {'video_id': '51W4t4SfHQs', 'title': 'Découvrez les portefeuilles mondiaux socialement responsables de Tangerine', 'published_at': '2022-02-18T02:16:59Z', 'views': '383', 'likes': '2', 'comments': '3', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 150.0}
# {'video_id': '_Vd8VXtbFPs', 'title': 'Get to Know Tangerine’s Socially Responsible Global Portfolios', 'published_at': '2022-02-18T02:16:48Z', 'views': '772', 'likes': '9', 'comments': '2', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 151.0}
# {'video_id': 'wM4cs5W9dOk', 'title': 'Investissements Tangerine – Récoltez le fruit de vos valeurs', 'published_at': '2022-01-21T17:30:41Z', 'views': '226', 'likes': '1', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 31.0}
# {'video_id': 'SHN_GTNilKo', 'title': 'Tangerine - TOI', 'published_at': '2021-11-01T19:25:26Z', 'views': '755', 'likes': '5', 'comments': '1', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 31.0}
# {'video_id': 'VW7Klb-2hWA', 'title': 'Tangerine Clients Impacted by COVID-19 Surprised with Special News', 'published_at': '2020-10-22T13:05:24Z', 'views': '1635', 'likes': '15', 'comments': '17', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 184.0}
# {'video_id': 'wD7Gt6bgPKQ', 'title': 'Deux clientes impactées par la COVID-19 reçoivent d’excellentes nouvelles', 'published_at': '2020-10-22T13:05:10Z', 'views': '528', 'likes': '3', 'comments': '3', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 185.0}
# {'video_id': '3_cHozEGnOU', 'title': 'How to get started with Money Rules', 'published_at': '2020-10-15T19:16:37Z', 'views': '1313', 'likes': '4', 'comments': '1', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 45.0}
# {'video_id': '7Mwor_MdvrA', 'title': 'Comment configurer un PÉA', 'published_at': '2020-10-15T19:16:37Z', 'views': '526', 'likes': '3', 'comments': '1', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 43.0}
# {'video_id': 'LPWBN3ScIwk', 'title': 'Comment configurer une Tactique', 'published_at': '2020-10-15T19:16:37Z', 'views': '483', 'likes': '2', 'comments': '2', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 46.0}
# {'video_id': 'rIN3rQohekY', 'title': 'How to get started with an ASP', 'published_at': '2020-10-15T19:16:37Z', 'views': '1418', 'likes': '14', 'comments': '1', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 38.0}
# {'video_id': 'GawfS0lT118', 'title': 'Can an Estate Go Bankrupt?', 'published_at': '2019-09-25T14:41:32Z', 'views': '964', 'likes': '2', 'comments': '2', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 33.0}
# {'video_id': '0lEAjjIBk9A', 'title': 'What Happens to Your Debts When You Die?', 'published_at': '2019-09-25T14:38:35Z', 'views': '1044', 'likes': '4', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 51.0}
# {'video_id': 'BwRIMuwmejY', 'title': 'Managing the Assets and Debts in Your Estate', 'published_at': '2019-09-25T14:34:26Z', 'views': '966', 'likes': '2', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 50.0}
# {'video_id': '9nRpgqlp_1c', 'title': 'Dying Without a Will', 'published_at': '2019-09-25T14:31:01Z', 'views': '1005', 'likes': '6', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 40.0}
# {'video_id': 'VOAb1uBSlQo', 'title': 'Who Needs a Will?', 'published_at': '2019-09-25T14:28:17Z', 'views': '703', 'likes': '1', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 41.0}
# {'video_id': 'pVyamH6w-Vk', 'title': "What's my Marginal Tax Rate?", 'published_at': '2019-09-25T14:25:02Z', 'views': '984', 'likes': '3', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 39.0}
# {'video_id': 'GdHdeZ2XH2Q', 'title': 'How Do You Calculate How Much Federal Income Tax You Owe?', 'published_at': '2019-09-25T14:19:08Z', 'views': '1392', 'likes': '6', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 40.0}
# {'video_id': 'Tj_w5CZqh4c', 'title': 'What are Tax Brackets?', 'published_at': '2019-09-25T14:12:45Z', 'views': '349', 'likes': '0', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 33.0}
# {'video_id': 'PFdA3RJJ-ms', 'title': 'Pauleanna Reid - Money Lessons', 'published_at': '2019-06-28T13:52:46Z', 'views': '656', 'likes': '4', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 42.0}
# {'video_id': 'TXZsxzGhvC8', 'title': 'Pauleanna Reid - Money Lessons', 'published_at': '2019-06-28T13:52:41Z', 'views': '608', 'likes': '5', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 34.0}
# {'video_id': 'cNHBgF6B11k', 'title': 'Pauleanna Reid - Money Lessons', 'published_at': '2019-06-27T17:57:47Z', 'views': '1004', 'likes': '12', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 116.0}
# {'video_id': 'cxBqfGmKOCo', 'title': 'What a run - NBA Champions', 'published_at': '2019-06-14T16:48:48Z', 'views': '104598', 'likes': '37', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 16.0}
# {'video_id': 'qi64AfBan1c', 'title': 'Full-time Nomad - Money Lessons', 'published_at': '2019-03-08T15:58:40Z', 'views': '1607', 'likes': '17', 'comments': '3', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 121.0}
# {'video_id': '4YPOgM9LsLQ', 'title': 'Full-time Nomad - Money Lessons', 'published_at': '2019-03-07T20:08:58Z', 'views': '736', 'likes': '5', 'comments': '6', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 32.0}
# {'video_id': 'AyZZTNL2DAQ', 'title': 'Full-time Nomad - Money Lessons', 'published_at': '2019-03-07T20:08:51Z', 'views': '686', 'likes': '5', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 59.0}
# {'video_id': 'jttl1TUoHhU', 'title': 'FTFS   Home Renos 10s H v06', 'published_at': '2019-02-25T04:05:53Z', 'views': '606', 'likes': '1', 'comments': '0', 'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'duration_seconds': 11.0}
# {'channel_id': 'UCm4E1b5TjstT8UUIk7mb-MA', 'title': 'Wise', 'subscribers': '51500', 'views': '1684436', 'total_videos': '99', 'playlist_id': 'UUm4E1b5TjstT8UUIk7mb-MA'}
# {'channel_id': 'UC-HnC-dcg5_KYW6pQ7H4JQA', 'title': 'KOHO', 'subscribers': '2850', 'views': '11542084', 'total_videos': '27', 'playlist_id': 'UU-HnC-dcg5_KYW6pQ7H4JQA'}
# {'channel_id': 'UCsMDZ4GA5pgLAxjc8TKjFiQ', 'title': 'Tangerine', 'subscribers': '5870', 'views': '2607066', 'total_videos': '312', 'playlist_id': 'UUsMDZ4GA5pgLAxjc8TKjFiQ'}

# %%
# Function to create channels table
def create_channels_table(conn):
    sql_create_channels_table = """
    CREATE TABLE IF NOT EXISTS channels (
        id TEXT PRIMARY KEY,
        title TEXT,
        subscribers INTEGER,
        views INTEGER,
        total_videos INTEGER,
        playlist_id TEXT
    );
    """
    try:
        cursor = conn.cursor()
        cursor.execute(sql_create_channels_table)
        conn.commit()
        print("Channels table created successfully.")
    except sqlite3.Error as e:
        print(f"Error creating channels table: {e}")

# Function to create videos table
def create_videos_table(conn):
    sql_create_videos_table = """
    CREATE TABLE IF NOT EXISTS videos (
        id TEXT PRIMARY KEY,
        title TEXT,
        published_date TEXT,
        views INTEGER,
        likes INTEGER,
        comments INTEGER,
        channel_id TEXT,
        duration_seconds INTEGER,
        FOREIGN KEY (channel_id) REFERENCES channels(channel_id)
    );
    """
    try:
        cursor = conn.cursor()
        cursor.execute(sql_create_videos_table)
        conn.commit()
        print("Videos table created successfully.")
    except sqlite3.Error as e:
        print(f"Error creating videos table: {e}")

# Main function to execute database operations
def main():
    try:
        # Connect to SQLite database (create it if it doesn't exist)
        conn = sqlite3.connect('youtube_data.db')
        print("Connected to SQLite database.")
        
        # Create channels and videos tables
        create_channels_table(conn)
        create_videos_table(conn)
        
    except sqlite3.Error as e:
        print(f"SQLite error: {e}")
    finally:
        if conn:
            conn.close()
            print("SQLite connection closed.")

if __name__ == "__main__":
    main()
# Out:
# Connected to SQLite database.
# Channels table created successfully.
# Videos table created successfully.
# SQLite connection closed.

# %%
def fetch_youtube_data(channel_ids):
    channel_stats = get_channel_stats(youtube, channel_ids)
    
    all_video_details = []
    for channel in channel_stats:
        print(f"Fetching videos for channel: {channel['title']}")
        playlist_id = channel['playlist_id']
        video_ids = get_video_ids(youtube, playlist_id)
        video_details = get_video_details(youtube, video_ids, channel_stats)
        all_video_details.extend(video_details)
    
    return channel_stats, all_video_details

# %%
# Function to insert data into SQL tables
def insert_data_into_sql(channel_stats, video_details):
    # Connect to SQLite database (or any other SQL database)
    conn = sqlite3.connect('youtube_data.db')
    cursor = conn.cursor()
    
    try:
        # Insert channel data into 'channels' table
        for channel in channel_stats:
            cursor.execute("""
                INSERT INTO channels (id, title, subscribers, views, total_videos, playlist_id)
                VALUES (?, ?, ?, ?, ?, ?)
            """, (
                channel['channel_id'],
                channel['title'],
                channel['subscribers'],
                channel['views'],
                channel['total_videos'],
                channel['playlist_id']
            ))
        
        # Insert video data into 'videos' table
        for video in video_details:
            # Convert published_at datetime to date
            published_date = datetime.strptime(video['published_at'], '%Y-%m-%dT%H:%M:%SZ').date()
            
            cursor.execute("""
                INSERT INTO videos (id, title, published_date, views, likes, comments, channel_id, duration_seconds)
                VALUES (?, ?, ?, ?, ?, ?, ?, ?)
            """, (
                video['video_id'],
                video['title'],
                published_date,
                video['views'],
                video['likes'],
                video['comments'],
                video['channel_id'],
                video['duration_seconds']
            ))
        
        # Commit changes and close connection
        conn.commit()
        print("Data inserted successfully into SQL tables.")
    
    except sqlite3.Error as e:
        print(f"Error inserting data: {e}")
    
    finally:
        conn.close()

# Main function to orchestrate the process
def main():
    # List of YouTube channel IDs for the three bank channels

    # List of YouTube channel IDs
    channel_ids = list(channel_ids_dict.values())

    # Fetch data from YouTube API
    channel_stats, video_details = fetch_youtube_data(channel_ids)

    # Insert data into SQL tables
    insert_data_into_sql(channel_stats, video_details)


if __name__ == "__main__":
    main()
# Out:
# Fetching videos for channel: KOHO
# Fetching videos for channel: Wise
# Fetching videos for channel: Tangerine
# Data inserted successfully into SQL tables.

# %%
# Function to execute SQL queries and fetch results
def execute_query(query):
    conn = sqlite3.connect('youtube_data.db')
    cursor = conn.cursor()
    
    try:
        cursor.execute(query)
        results = cursor.fetchall()
        return results
    except sqlite3.Error as e:
        print(f"Error executing query: {e}")
    finally:
        conn.close()

# Query 1: Count of Videos per Channel
query1 = """
    SELECT
        c.title AS channel_title,
        COUNT(v.id) AS video_count
    FROM
        channels c
    LEFT JOIN
        videos v ON c.id = v.channel_id
    GROUP BY
        c.title
    ORDER BY
        video_count DESC;
"""

# Query 2: Average Views per Video
query2 = """
    SELECT
        c.title AS channel_title,
        AVG(v.views) AS avg_views_per_video
    FROM
        channels c
    LEFT JOIN
        videos v ON c.id = v.channel_id
    GROUP BY
        c.title
    ORDER BY
        avg_views_per_video DESC;
"""

# Query 3: Views to Comment Ratio
query3 = """
    SELECT
        c.title AS channel_title,
        SUM(v.views) AS total_views,
        SUM(v.comments) AS total_comments,
        CASE
            WHEN SUM(v.comments) > 0 THEN SUM(v.views) / SUM(v.comments)
            ELSE 0
        END AS views_to_comment_ratio
    FROM
        channels c
    LEFT JOIN
        videos v ON c.id = v.channel_id
    GROUP BY
        c.title
    ORDER BY
        views_to_comment_ratio DESC;
"""

# Execute and print results for Query 1
print("Query 1: Count of Videos per Channel")
results1 = execute_query(query1)
for row in results1:
    print(row)

# Execute and print results for Query 2
print("\nQuery 2: Average Views per Video")
results2 = execute_query(query2)
for row in results2:
    print(row)

# Execute and print results for Query 3
print("\nQuery 3: Views to Comment Ratio")
results3 = execute_query(query3)
for row in results3:
    print(row)
# Out:
# Query 1: Count of Videos per Channel
# ('Wise', 50)
# ('Tangerine', 50)
# ('KOHO', 28)
#
# Query 2: Average Views per Video
# ('KOHO', 413382.6785714286)
# ('Tangerine', 9022.06)
# ('Wise', 4824.58)
#
# Query 3: Views to Comment Ratio
# ('KOHO', 11574715, 361, 32062)
# ('Tangerine', 451103, 89, 5068)
# ('Wise', 241229, 1481, 162)

# %%
# Function to fetch data from SQLite and export to CSV
def export_to_csv(table_name, file_name):
    conn = sqlite3.connect('youtube_data.db')
    cursor = conn.cursor()
    
    # Fetch data from the table
    cursor.execute(f"SELECT * FROM {table_name};")
    data = cursor.fetchall()
    
    # Export data to CSV
    with open(file_name, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        # Write header (column names)
        csv_writer.writerow([description[0] for description in cursor.description])
        # Write data rows
        csv_writer.writerows(data)
    
    conn.close()

# Export channels table to CSV
export_to_csv('channels', 'channels.csv')

# Export videos table to CSV
export_to_csv('videos', 'videos.csv')

print("Export to CSV complete.")
# Out:
# Export to CSV complete.
